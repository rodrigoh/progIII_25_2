# %% [markdown]
# # Importando o pandas

# %%
#Esse comando funciona dentro do google colab
#!pip install --upgrade pandas

# %%
#importando o pandas
import pandas as pd

# %%
#Configurando para que os floats tenham duas cadas decimais
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# # Dados de exemplo

# %%
#Criando um dicionário
dados = {
   'Nome': ['Alice', 'Bruno','Carlos','Daniela'],
   'Idade':[25, 20, 22, 27],
   'Salário':[3000, 4500, 2500, 5200]
}
print(dados)
# Out:
# {'Nome': ['Alice', 'Bruno', 'Carlos', 'Daniela'], 'Idade': [25, 20, 22, 27], 'Salário': [3000, 4500, 2500, 5200]}

# %%
#Convertendo para dataFrame
df = pd.DataFrame(dados)
df
#Dentro de um arquivo .py
#print(df)
# Out:
#       Nome  Idade  Salário
# 0    Alice     25     3000
# 1    Bruno     20     4500
# 2   Carlos     22     2500
# 3  Daniela     27     5200

# %%
#df = pd.read_csv('https://fit.faccat.br/~rh/datasets/a5/streaming_preferences.csv')
#df = pd.read_csv('sample_data/streaming_preferences.csv')
df = pd.read_csv('dataset/streaming_preferences.csv')

# %% [markdown]
# #Verificando a quatidade de linhas e colunas do dataframe

# %%
#Mostra a quantidade linhas e colunas do dataset
df.shape
# Out:
# (5000, 12)

# %% [markdown]
# # Olhando as n primeiras do dataframe

# %%
df.head(10)
# Out:
#   User_ID  Age      Country Streaming Platform  Top Genre  \
# 0   U1000   34        Japan              Tidal     Reggae
# 1   U1001   24      Germany             Deezer    Country
# 2   U1002   49      Germany             Deezer        Pop
# 3   U1003   55    Australia            YouTube     Reggae
# 4   U1004   13      Germany       Amazon Music     Reggae
# 5   U1005   25  South Korea            Spotify        EDM
# 6   U1006   49    Australia              Tidal    Country
# 7   U1007   32           UK       Amazon Music  Classical
# 8   U1008   25      Germany              Tidal      Metal
# 9   U1009   37       Brazil            Spotify     Reggae
#
#    Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# 0                       295                    138              Adele
# 1                        86                    388         Ed Sheeran
# 2                       363                    368        Post Malone
# ...

# %% [markdown]
# # Olhando as n linhas finais do dataframe

# %%
df.tail(10)
# Out:
#      User_ID  Age      Country Streaming Platform  Top Genre  \
# 4990   U5990   32          USA       Amazon Music        EDM
# 4991   U5991   27  South Korea            Spotify        R&B
# 4992   U5992   46           UK        Apple Music    Hip-Hop
# 4993   U5993   19      Germany              Tidal       Jazz
# 4994   U5994   55    Australia       Amazon Music  Classical
# 4995   U5995   60           UK             Deezer    Country
# 4996   U5996   38    Australia             Deezer    Hip-Hop
# 4997   U5997   27       Brazil       Amazon Music      Metal
# 4998   U5998   58       Canada       Amazon Music        EDM
# 4999   U5999   30  South Korea            YouTube       Rock
#
#       Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# 4990                       511                    136          Bad Bunny
# 4991                        51                    166        Post Malone
# ...

# %% [markdown]
# # Mostrando informações do dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   User_ID                                   5000 non-null   object
#  1   Age                                       5000 non-null   int64
#  2   Country                                   5000 non-null   object
#  3   Streaming Platform                        5000 non-null   object
#  4   Top Genre                                 5000 non-null   object
#  5   Minutes Streamed Per Day                  5000 non-null   int64
#  6   Number of Songs Liked                     5000 non-null   int64
#  7   Most Played Artist                        5000 non-null   object
#  8   Subscription Type                         5000 non-null   object
#  9   Listening Time (Morning/Afternoon/Night)  5000 non-null   object
# ...

# %% [markdown]
# # Monstrando a descrição dos dados

# %%
df.describe(include='all')
# Out:
#        User_ID     Age    Country Streaming Platform Top Genre  \
# count     5000 5000.00       5000               5000      5000
# unique    5000     NaN         10                  6        10
# top      U1000     NaN  Australia       Amazon Music    Reggae
# freq         1     NaN        526                861       532
# mean       NaN   36.66        NaN                NaN       NaN
# std        NaN   13.76        NaN                NaN       NaN
# min        NaN   13.00        NaN                NaN       NaN
# 25%        NaN   25.00        NaN                NaN       NaN
# 50%        NaN   37.00        NaN                NaN       NaN
# 75%        NaN   49.00        NaN                NaN       NaN
# max        NaN   60.00        NaN                NaN       NaN
#
#         Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# count                    5000.00                5000.00               5000
# ...

# %% [markdown]
# # Contando os dados nulos

# %%
df.isnull().sum()
# Out:
# User_ID                                     0
# Age                                         0
# Country                                     0
# Streaming Platform                          0
# Top Genre                                   0
# Minutes Streamed Per Day                    0
# Number of Songs Liked                       0
# Most Played Artist                          0
# Subscription Type                           0
# Listening Time (Morning/Afternoon/Night)    0
# Discover Weekly Engagement (%)              0
# Repeat Song Rate (%)                        0
# dtype: int64

# %% [markdown]
# #Contagem de valores únicos de cada coluna

# %%
df.nunique()
# Out:
# User_ID                                     5000
# Age                                           48
# Country                                       10
# Streaming Platform                             6
# Top Genre                                     10
# Minutes Streamed Per Day                     591
# Number of Songs Liked                        500
# Most Played Artist                            10
# Subscription Type                              2
# Listening Time (Morning/Afternoon/Night)       3
# Discover Weekly Engagement (%)              3687
# Repeat Song Rate (%)                        3687
# dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['Japan', 'Germany', 'Australia', 'South Korea', 'UK', 'Brazil',
#        'Canada', 'India', 'USA', 'France'], dtype=object)

# %%
for coluna in df.columns:
    print(f'{coluna} {df[coluna].unique()}')
#df['Country'].unique()
# Out:
# User_ID ['U1000' 'U1001' 'U1002' ... 'U5997' 'U5998' 'U5999']
# Age [34 24 49 55 13 25 32 37 40 43 46 57 23 33 19 16 17 39 29 42 35 53 27 51
#  47 58 38 26 50 56 54 14 48 20 30 18 60 52 59 22 36 31 21 41 45 28 44 15]
# Country ['Japan' 'Germany' 'Australia' 'South Korea' 'UK' 'Brazil' 'Canada'
#  'India' 'USA' 'France']
# Streaming Platform ['Tidal' 'Deezer' 'YouTube' 'Amazon Music' 'Spotify' 'Apple Music']
# Top Genre ['Reggae' 'Country' 'Pop' 'EDM' 'Classical' 'Metal' 'Rock' 'Hip-Hop' 'R&B'
#  'Jazz']
# Minutes Streamed Per Day [295  86 363 348  30 536 547  98 526 514 266 351 389 506 502 193 542  13
#  383 147  58 450 445 218  87 537 203 267 151  60 201 564 140 187 332  99
#  265 370 478 581  93 463  84 404 149 585 485 249 225 414 189  88  43 259
#  202 429 282  67 587 262 372 229 316 334 580 538 394 228 570 342 530 251
#  331 435 419 364  23 365 574 474 252 123  49 217 222  31 426 578 451 454
#  283 136 311  11 379 327 131 476 144  74  76 473 539 318 199 531 234 386
# ...

# %% [markdown]
# # Selecionando dados

# %%
pais = df[['Country', 'Top Genre', 'Age']]
pais
# Out:
#           Country Top Genre  Age
# 0           Japan    Reggae   34
# 1         Germany   Country   24
# 2         Germany       Pop   49
# 3       Australia    Reggae   55
# 4         Germany    Reggae   13
# ...           ...       ...  ...
# 4995           UK   Country   60
# 4996    Australia   Hip-Hop   38
# 4997       Brazil     Metal   27
# 4998       Canada       EDM   58
# 4999  South Korea      Rock   30
#
# [5000 rows x 3 columns]

# %%
#Obtendo o registro pelo índice
df.iloc[3]
# Out:
# User_ID                                         U1003
# Age                                                55
# Country                                     Australia
# Streaming Platform                            YouTube
# Top Genre                                      Reggae
# Minutes Streamed Per Day                          348
# Number of Songs Liked                             349
# Most Played Artist                           Dua Lipa
# Subscription Type                             Premium
# Listening Time (Morning/Afternoon/Night)      Morning
# Discover Weekly Engagement (%)                  31.27
# Repeat Song Rate (%)                            76.51
# Name: 3, dtype: object

# %%
# Obtendo um registro e uma coluna específica
print(df.loc[10,['Age','Streaming Platform']])
print(df.loc[10,'Age'])
# Out:
# Age                       40
# Streaming Platform    Deezer
# Name: 10, dtype: object
# 40

# %%
df[(df['Country']=='Brazil') & (df['Top Genre'] == 'Reggae') & (df['Subscription Type']=='Free')]
# Out:
#      User_ID  Age Country Streaming Platform Top Genre  \
# 100    U1100   17  Brazil            YouTube    Reggae
# 603    U1603   27  Brazil            Spotify    Reggae
# 756    U1756   21  Brazil       Amazon Music    Reggae
# 890    U1890   45  Brazil              Tidal    Reggae
# 1006   U2006   43  Brazil              Tidal    Reggae
# 1679   U2679   57  Brazil       Amazon Music    Reggae
# 1759   U2759   19  Brazil              Tidal    Reggae
# 1857   U2857   49  Brazil       Amazon Music    Reggae
# 2072   U3072   35  Brazil            YouTube    Reggae
# 2109   U3109   59  Brazil            Spotify    Reggae
# 2228   U3228   24  Brazil              Tidal    Reggae
# 2282   U3282   36  Brazil            Spotify    Reggae
# 2824   U3824   21  Brazil            Spotify    Reggae
# 3128   U4128   59  Brazil       Amazon Music    Reggae
# 3474   U4474   23  Brazil            Spotify    Reggae
# 3734   U4734   46  Brazil            Spotify    Reggae
# ...

# %%
df[(df['Country']=='Brazil') & (df['Age']>30)]
# Out:
#      User_ID  Age Country Streaming Platform  Top Genre  \
# 9      U1009   37  Brazil            Spotify     Reggae
# 11     U1011   43  Brazil            Spotify       Rock
# 22     U1022   40  Brazil              Tidal       Jazz
# 23     U1023   42  Brazil       Amazon Music       Rock
# 25     U1025   53  Brazil        Apple Music     Reggae
# ...      ...  ...     ...                ...        ...
# 4924   U5924   31  Brazil              Tidal        Pop
# 4938   U5938   34  Brazil              Tidal       Rock
# 4947   U5947   35  Brazil       Amazon Music  Classical
# 4955   U5955   34  Brazil        Apple Music    Hip-Hop
# 4983   U5983   45  Brazil              Tidal       Rock
#
#       Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# 9                          514                    299      Billie Eilish
# 11                         351                    108              Drake
# ...

# %% [markdown]
# #Alterando dados

# %%
#Criando uma  nova coluna
#df['idade'] = df['Age']+1
#Manipilar uma coluna que já existe
df['Age'] = df['Age']+1
#df['Age']+=1
df
# Out:
#      User_ID  Age      Country Streaming Platform Top Genre  \
# 0      U1000   46        Japan              Tidal    Reggae
# 1      U1001   36      Germany             Deezer   Country
# 2      U1002   61      Germany             Deezer       Pop
# 3      U1003   67    Australia            YouTube    Reggae
# 4      U1004   25      Germany       Amazon Music    Reggae
# ...      ...  ...          ...                ...       ...
# 4995   U5995   72           UK             Deezer   Country
# 4996   U5996   50    Australia             Deezer   Hip-Hop
# 4997   U5997   39       Brazil       Amazon Music     Metal
# 4998   U5998   70       Canada       Amazon Music       EDM
# 4999   U5999   42  South Korea            YouTube      Rock
#
#       Minutes Streamed Per Day  Number of Songs Liked Most Played Artist  \
# 0                          295                    138              Adele
# 1                           86                    388         Ed Sheeran
# ...

# %%
#Apagando uma coluna
df.drop('User_ID',axis=1,inplace=True)

# %%
df.drop_duplicates()
# Out:
#       Age      Country Streaming Platform Top Genre  Minutes Streamed Per Day  \
# 0      37        Japan              Tidal    Reggae                       295
# 1      27      Germany             Deezer   Country                        86
# 2      52      Germany             Deezer       Pop                       363
# 3      58    Australia            YouTube    Reggae                       348
# 4      16      Germany       Amazon Music    Reggae                        30
# ...   ...          ...                ...       ...                       ...
# 4995   63           UK             Deezer   Country                       348
# 4996   41    Australia             Deezer   Hip-Hop                       225
# 4997   30       Brazil       Amazon Music     Metal                       568
# 4998   61       Canada       Amazon Music       EDM                       523
# 4999   33  South Korea            YouTube      Rock                       451
#
# ...

# %%
df.sort_values(['Age','Country'], ascending=[True, False],inplace=True)

# %%
df
# Out:
#       Age    Country Streaming Platform  Top Genre  Minutes Streamed Per Day  \
# 124    16        USA        Apple Music  Classical                        44
# 690    16        USA             Deezer  Classical                       483
# 691    16        USA       Amazon Music      Metal                       189
# 885    16        USA       Amazon Music     Reggae                        14
# 972    16        USA            YouTube     Reggae                       454
# ...   ...        ...                ...        ...                       ...
# 3133   63  Australia             Deezer        EDM                        32
# 3138   63  Australia            YouTube      Metal                        98
# 3386   63  Australia            YouTube      Metal                       354
# 3782   63  Australia       Amazon Music       Jazz                       582
# 4284   63  Australia            Spotify    Hip-Hop                       215
#
# ...

# %% [markdown]
# # Alterando o tipo de uma coluna

# %%
dados = {'Gasto': ['1200,50', 3500.75, '950,30']}

# %%
df = pd.DataFrame(dados)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gasto   3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
df['Gasto'] = df['Gasto'].astype(str).str.replace(',' , '.').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gasto   3 non-null      float64
# dtypes: float64(1)
# memory usage: 156.0 bytes

# %%
df
# Out:
#      Gasto
# 0  1200.50
# 1  3500.75
# 2   950.30

# %%
df.to_csv('sample_data/dados_novos.csv',index=False)

# %%
df.to_excel('sample_data/dados_novos.xlsx',index=False)
